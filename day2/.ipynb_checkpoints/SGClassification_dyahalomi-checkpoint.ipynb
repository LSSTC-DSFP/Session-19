# %% [markdown]
# This notebook guides you through an exercise in star/galaxy/quasar classification, using k Nearest Neighbors and Decision Trees algorithm.
#
# Written with ❤️ by Viviana Acquaviva for the LSST Data Science Fellowship lecture series.
#
# License: [BSD-3-clause](https://opensource.org/license/bsd-3-clause/)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.preprocessing import StandardScaler
from sklearn import metrics 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict, cross_validate
from sklearn.model_selection import KFold, StratifiedKFold

# %% [markdown]
# We can read the data here. They were taken by the Sloan Digital Sky Survey and come from [Kaggle](https://www.kaggle.com/datasets/divyansh22/dummy-astronomy-data).

# %%
data = pd.read_csv('star_classification.csv', sep = ',')

df = data.sample(frac = 0.2, random_state = 11) #randomly select 20% of the data

df.reset_index(drop = True, inplace=True)

# %% [markdown]
# Let's learn a few things about this data frame.

# %%
df.columns
# Out:
# Index(['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
#        'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'class', 'redshift',
#        'plate', 'MJD', 'fiber_ID'],
#       dtype='object')

# %% [markdown]
# We can get some basic info about the data (numerical columns only!) like this.

# %%
df.describe()
# Out:
#              obj_ID         alpha         delta             u             g  \
# count  2.000000e+04  20000.000000  20000.000000  20000.000000  20000.000000
# mean   1.237665e+18    177.842440     24.090014     21.570237     20.112328
# std    8.494500e+12     96.449277     19.671442     70.895801     70.878771
# min    1.237646e+18      0.011684    -18.785328  -9999.000000  -9999.000000
# 25%    1.237659e+18    128.062911      4.792074     20.326388     18.948163
# 50%    1.237663e+18    181.844138     23.669408     22.181680     21.103180
# 75%    1.237668e+18    234.300980     39.764756     23.699415     22.111157
# max    1.237681e+18    359.978910     79.289299     32.781390     28.903200
#
#                   r             i             z        run_ID  rerun_ID  \
# count  20000.000000  20000.000000  20000.000000  20000.000000   20000.0
# mean      19.631559     19.072001     18.258834   4484.174000     301.0
# std        1.865094      1.767396     70.858525   1977.787496       0.0
# min       10.068540     10.566470  -9999.000000    109.000000     301.0
# 25%       18.114108     17.688330     17.426372   3185.000000     301.0
# 50%       20.116750     19.390850     18.990105   4188.000000     301.0
# 75%       21.026725     20.370548     19.914907   5327.000000     301.0
# max       29.571860     30.154600     29.383740   8162.000000     301.0
#
#             cam_col      field_ID   spec_obj_ID      redshift         plate  \
# count  20000.000000  20000.000000  2.000000e+04  20000.000000  20000.000000
# mean       3.504450    185.671850  5.744512e+18      0.569276   5102.041700
# std        1.584268    148.777943  3.307683e+18      0.717889   2937.795949
# min        1.000000     11.000000  2.996213e+17     -0.009971    266.000000
# 25%        2.000000     81.000000  2.840735e+18      0.052374   2523.000000
# 50%        4.000000    146.000000  5.507912e+18      0.420752   4892.000000
# 75%        5.000000    239.000000  8.251792e+18      0.696156   7329.000000
# max        6.000000    989.000000  1.412685e+19      7.011245  12547.000000
#
#                 MJD      fiber_ID
# count  20000.000000  20000.000000
# mean   55570.825150    449.194850
# std     1801.149748    272.016573
# min    51608.000000      1.000000
# 25%    54232.750000    222.000000
# 50%    55858.000000    433.000000
# 75%    56749.000000    641.000000
# max    58932.000000   1000.000000

# %% [markdown]
# What should be our features and targets?

# %%
#photometry should be the features.... so u, g, r, i, z
#probably also redshift has some information.... but if you know redshift you probably know the class... so don't use

#labels (same as target) are the classes..... so class

# %% [markdown]
# We can select the following columns:

# %%
seldf = df[['u','g','r','i','z']]

# %% [markdown]
# ### Feature exploration.
#
# What should we do?

# %%
#plot a histogram

# %%
for col in seldf.columns:
    plt.hist(seldf[col], alpha = 0.5)

# %% [markdown]
# When a histogram looks like this, what does it mean?
#
# - some giant outliers are dominating the range

# %%
for col in seldf.columns:
    plt.hist(seldf[col], alpha = 0.5, bins=100, range = (0,30))

# %%
#print number of all photometry with a negative values
for col in seldf.columns:
    print(len(np.where(seldf[col] < 0)[0]))
# Out:
# 1
# 1
# 0
# 0
# 1

# %% [markdown]
# One possible (less than ideal) selection:

# %%
#remove all photometry with a negative values
for col in seldf.columns:
    seldf = seldf[seldf[col] >= 0]

# %%
seldf.shape
# Out:
# (19999, 5)

# %%
for col in seldf.columns:
    plt.hist(seldf[col], alpha = 0.5, bins=100)

# %% [markdown]
# Let's now turn to the target column.

# %%
#print all the unique labels
np.unique(df['class'])
# Out:
# array(['GALAXY', 'QSO', 'STAR'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

#sklearn can't use strings....so convert label names to integer values

le = LabelEncoder() #turns categorical into 1 ... N

# %%
y = le.fit_transform(df['class'].values)
print(y)
# Out:
# [0 1 2 ... 0 2 2]

# %%
le.classes_
# Out:
# array(['GALAXY', 'QSO', 'STAR'], dtype=object)

# %% [markdown]
# It is also useful to know which class was mapped to which number!

# %%
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping)


# be aware that this introduces a distance because now galaxy is implicitly further from star than qso
# ... for ... 2 or 3 classes its not a big deal ... but the more classes the bigger an issue this becomes
# can you a column ie [[1,0,0][0,1,0],[0,0,1]] (i think?) to get around this...?
# Out:
# {'GALAXY': 0, 'QSO': 1, 'STAR': 2}

# %%
np.unique(y)
# Out:
# array([0, 1, 2])

# %% [markdown]
# We can now plot the class distribution to see if something stands out.

# %%
plt.hist(y);

# %% [markdown]
# Verdict: Is there anything we should keep in mind?

# %%
# galaxies are the most abundant, then stars, then QSOs
# be careful bc ML can learn about the distribution and the number of each objects
# ie if we train on a distribution with a huge number of one class and then apply it
# to a different distribution, then could be innacurate for the new dataset


# in general though, this is only a facotr of ~3 difference at the extreme... 
# generally we are ok as long as we don't have a extreme difference in the quantities
# (where extreme is something larger than a factor of say ~5 or 10)


# if this is the case, you could either _____ (missed this) or downselect from your extreme group
# ie if there were 10x the galaxies than stars, randomly choose 10% of the galaxies and train on that set

# %%
target = y[seldf.index]

# %% [markdown]
# Now that we have our feature matrix and target vector, we could try and build a model, or try to get some more intel on the relationship between features and target. One way is to build a correlation matrix (easiest with seaborn); another one that I like when there are very few features like in this case, is to make scatter plots of the features and color the points by the label, to see if any obvious gradient shows up.

# %%
len(seldf.columns)
# Out:
# 5

# %%
#It will take a little time.

fig, axes = plt.subplots(ncols = len(seldf.columns), nrows = len(seldf.columns), figsize=(50,50))

for i, col in enumerate(seldf.columns):
    for j, col2 in enumerate(seldf.columns):
        axes[i,j].scatter(seldf[col], seldf[col2], c = target)
        axes[i,j].set_xlabel(str(seldf[col].name), fontsize = 35)
        axes[i,j].set_ylabel(str(seldf[col2].name), fontsize = 35)

# %% [markdown]
# Q: Is there anything special that we can learn from these plots? Do we expect our features to have enough discriminating power? Why or why not?

# %%
# QSOs (quasars) (green) and stars (purple) seem to live in their own space so probably can seperate these out
# galaxies (yellow) seem more spread throughout, so may be more difficult

# %% [markdown]
# ### Building models

# %% [markdown]
# Alright, time to build our first model - let's start with kNN.

# %% [markdown]
# This line helps visualize the parameters of any algorithm.

# %%
model_KNN = KNeighborsClassifier()
model_KNN.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %% [markdown]
# We can set up a cross validation strategy like this.

# %%
cv = KFold(n_splits=5, random_state=10, shuffle= True)

# %% [markdown]
# This line does the cross validation for us by randomizing the data, creating five folds, building 5 models with the 5 possible training sets, applying each model to the objects in the test fold, and saving the 5 train and test scores in a dictionary.

# %%
scores_KNN = cross_validate(model_KNN, seldf, target, cv = cv, return_train_score = True)
scores_KNN
# Out:
# {'fit_time': array([0.01272202, 0.00785303, 0.00790119, 0.00780535, 0.00819898]),
#  'score_time': array([0.09395504, 0.0848372 , 0.08052206, 0.08135772, 0.08180594]),
#  'test_score': array([0.84075   , 0.8495    , 0.852     , 0.84825   , 0.84096024]),
#  'train_score': array([0.88674292, 0.88468029, 0.8848053 , 0.88530533, 0.8851875 ])}

# %%
print("Time: %.3fs, Mean train score: %.3f, Mean test score: %.3f, std: %.3f"%(scores['score_time'].mean(), scores['train_score'].mean(), scores['test_score'].mean(), scores['test_score'].std()))
# Out:
# Time: 0.084s, Mean train score: 0.885, Mean test score: 0.846, std: 0.005

# %% [markdown]
# Let us now set up a decision tree classifier with default parameters:

# %%
model_DT = DecisionTreeClassifier()

# %%
model_DT.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# Decision trees are more complex than kNN and have a few more hyperparameters to play with. They include:
# - the minimum number of instances in a leaf node;
# - the minimum number of instances required in a split node;
# - the maximum depth of tree;
# - the minimum information gain required to decide whether a split is "worth it".

# %%
scores_DT = cross_validate(model_DT, seldf, target, cv = cv, return_train_score=True)

# %%
print("Time: %.3fs, Mean train score: %.3f, Mean test score: %.3f, std: %.3f"%(scores['score_time'].mean(), scores['train_score'].mean(), scores['test_score'].mean(), scores['test_score'].std()))
# Out:
# Time: 0.084s, Mean train score: 0.885, Mean test score: 0.846, std: 0.005

# %% [markdown]
# Before sending you on your way with optimizing these models, let's also talk about the great function cross_val_predict. It is used to generate test predictions in the cross validation framework. Just like cross_validate, this line will randomize the data, create five folds (if the random seed is fixed, they will be consistent across our notebooks!), build 5 models with the 5 possible training sets, apply each model to the objects in the test fold, and compile together the predicted values from the 5 test folds. The output will be this vector of predicted values, which has the same size as the target vector.

# %%
ypred_DT = cross_val_predict(model_DT, seldf, target, cv = cv)
ypred_KNN = cross_val_predict(model_KNN, seldf, target, cv = cv)

# %% [markdown]
# Having these predictions is very useful because you can calculate more complex scores, or a confusion matrix (or a scatter plot of true vs predicted values in the case of regression).

# %%
print(metrics.confusion_matrix(target, ypred_DT))
print(metrics.confusion_matrix(target, ypred_KNN))
# Out:
# [[10472   592   865]
#  [  595  2608   534]
#  [  858   522  2953]]
# [[11092   360   477]
#  [  494  2868   375]
#  [  904   464  2965]]

# %% [markdown]
# Finally, I'm going to drop here this handy function to calculate and plot learning curves.

# %% [markdown]
# Learning curves are helpful in order to visualize the training scores vs the test scores, and how they vary as a function of data set size. They allow us to determine whether we have enough learning data, AND whether we have a high bias or high variance problem.
#
# The source code below is a slight modification of [this code](https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html).

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=5,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5), scoring = 'accuracy'):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    plt.figure(figsize=(10,6))
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel(str(scoring))
    
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring = scoring)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Test score from cross-validation")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# This is a demonstration of how to use the function:

# %%
plot_learning_curve(model_DT, 'DT (default params)', seldf, target,  cv = cv);

# %%
plot_learning_curve(model_KNN, 'KNN (default params)', seldf, target,  cv = cv);

# %% [markdown]
# In the case, above, would we say that
#
# - We have high bias or high variance? Why?
#     - DT: high variance because there is a statistically significant gap between the test and training errors
#     - KNN: high variance because there is a statistically significant gap between the test and training errors
#
# - We have enough training data or not? Why?
#     - DT: yes, becasue our test score from cross-validation plateus
#     - KNN: no, becasue our test score from cross-validation plateus

# %% [markdown]
# ### Tasks
#
# Feel free to do the ones you prefer according to your expertise level and personal preference!

# %% [markdown]
# 1. Consider (separately) the kNN and DT models with default parameters. Do they suffer from high variance or high bias? Why?
#
# 2. Based on your answer above, do you anticipate better results from making the model(s) more complex or simpler? How could this be implemented, in terms of choosing hyperparameters and their range?
#
#     - as the models are high variance, we should make them more simple?
#
#
# 3. Play around with hyperparameters for a model of your choice and see what test scores you can get! The highest score wins... a drink of their choice at Monday's dinner?
#
# 4. What's something I should have done for kNN and didn't? :)

# %%
model_DT = DecisionTreeClassifier(min_samples_leaf=10, min_impurity_decrease = .001, max_depth = 7)
scores_DT = cross_validate(model_DT, seldf, target, cv = cv, return_train_score=True)
print("Time: %.3fs, Mean train score: %.3f, Mean test score: %.3f, std: %.3f"%(scores_DT['score_time'].mean(), scores_DT['train_score'].mean(), scores_DT['test_score'].mean(), scores_DT['test_score'].std()))


ypred_DT = cross_val_predict(model_DT, seldf, target, cv = cv)
print(metrics.confusion_matrix(target, ypred_DT))
plot_learning_curve(model_DT, 'DT (default params)', seldf, target,  cv = cv);
# Out:
# Time: 0.001s, Mean train score: 0.803, Mean test score: 0.788, std: 0.009
# [[10836   339   754]
#  [  474  2644   619]
#  [ 1496   552  2285]]

# %%
model_KNN = KNeighborsClassifier(n_neighbors=9, leaf_size=18)
model_KNN.get_params()

scores_KNN = cross_validate(model_KNN, seldf, target, cv = cv, return_train_score = True)


print("Time: %.3fs, Mean train score: %.3f, Mean test score: %.3f, std: %.3f"%(scores_KNN['score_time'].mean(), scores['train_score'].mean(), scores_KNN['test_score'].mean(), scores_KNN['test_score'].std()))



ypred_KNN = cross_val_predict(model_KNN, seldf, target, cv = cv)
print(metrics.confusion_matrix(target, ypred_KNN))
plot_learning_curve(model_KNN, 'DT (default params)', seldf, target,  cv = cv);
# Out:
# Time: 0.089s, Mean train score: 0.885, Mean test score: 0.847, std: 0.003
# [[11124   332   473]
#  [  451  2876   410]
#  [  950   444  2939]]
